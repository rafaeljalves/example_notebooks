# %% [markdown]
# This notebook demonstrates an issue with the smart solvers. When a solver fails to solve a state, it still saves the final state (even if it contains NaNs) in the predictor. This flawed state is then used in the prediction for the subsequent solve call.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh")
# !conda config --remove channels defaults
# !conda config --add channels conda-forge
# !conda install reaktoro -y
# Out:
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:28
# 🔁 Restarting kernel...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - reaktoro
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     asttokens-2.4.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     attrs-23.2.0               |     pyh71513ae_0          53 KB  conda-forge
#     autodiff-1.0.3             |  py310h64a2142_1         703 KB  conda-forge
#     boltons-23.1.1             |     pyhd8ed1ab_0         297 KB  conda-forge
#     brotlipy-0.7.0             |py310h2372a71_1006         310 KB  conda-forge
#     bzip2-1.0.8                |       hd590300_5         248 KB  conda-forge
#     ca-certificates-2024.2.2   |       hbcca054_0         152 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     cffi-1.16.0                |  py310h2fee648_0         236 KB  conda-forge
#     chemicalfun-0.1.10         |  py310hd41b1e2_0         374 KB  conda-forge
#     comm-0.2.1                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     conda-23.7.4               |  py310hff52083_0        1006 KB  conda-forge
#     conda-package-handling-1.9.0|  py310h5764c6d_1        1016 KB  conda-forge
#     cryptography-42.0.2        |  py310hb8475ec_0         1.9 MB  conda-forge
#     debugpy-1.8.0              |  py310hc6cd4ac_1         2.3 MB  conda-forge
#     decorator-5.1.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     eigen-3.4.0                |       h00ab1b0_0         1.0 MB  conda-forge
#     exceptiongroup-1.2.0       |     pyhd8ed1ab_2          20 KB  conda-forge
#     executing-2.0.1            |     pyhd8ed1ab_0          27 KB  conda-forge
#     expat-2.5.0                |       hcb278e6_1         134 KB  conda-forge
#     fmt-10.2.1                 |       h00ab1b0_0         189 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_1         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     importlib-metadata-7.0.1   |     pyha770c72_0          26 KB  conda-forge
#     importlib_metadata-7.0.1   |       hd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.1.1  |     pyhd8ed1ab_0          29 KB  conda-forge
#     ipykernel-6.29.2           |     pyhd33586a_0         115 KB  conda-forge
#     ipython-8.21.0             |     pyh707e725_0         578 KB  conda-forge
#     jedi-0.19.1                |     pyhd8ed1ab_0         822 KB  conda-forge
#     jsonpatch-1.33             |     pyhd8ed1ab_0          17 KB  conda-forge
#     jsonpointer-2.4            |  py310hff52083_3          16 KB  conda-forge
#     jsonschema-4.21.1          |     pyhd8ed1ab_0          71 KB  conda-forge
#     jsonschema-specifications-2023.12.1|     pyhd8ed1ab_0          16 KB  conda-forge
#     jupyter_client-8.6.0       |     pyhd8ed1ab_0         103 KB  conda-forge
#     jupyter_core-5.7.1         |  py310hff52083_0          78 KB  conda-forge
#     kaleido-core-0.2.1         |       h3644ca4_0        59.2 MB  conda-forge
#     ld_impl_linux-64-2.40      |       h41732ed_0         688 KB  conda-forge
#     libblas-3.9.0              |21_linux64_openblas          14 KB  conda-forge
#     libcblas-3.9.0             |21_linux64_openblas          14 KB  conda-forge
#     libexpat-2.5.0             |       hcb278e6_1          76 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-ng-13.2.0           |       h807b86a_5         752 KB  conda-forge
#     libgfortran-ng-13.2.0      |       h69a702a_5          23 KB  conda-forge
#     libgfortran5-13.2.0        |       ha4646dd_5         1.4 MB  conda-forge
#     libgomp-13.2.0             |       h807b86a_5         410 KB  conda-forge
#     liblapack-3.9.0            |21_linux64_openblas          14 KB  conda-forge
#     libnsl-2.0.1               |       hd590300_0          33 KB  conda-forge
#     libopenblas-0.3.26         |pthreads_h413a1c8_0         5.3 MB  conda-forge
#     libpng-1.6.42              |       h2797004_0         282 KB  conda-forge
#     libsodium-1.0.18           |       h36c2ea0_1         366 KB  conda-forge
#     libsqlite-3.44.2           |       h2797004_0         826 KB  conda-forge
#     libstdcxx-ng-13.2.0        |       h7e041cc_5         3.7 MB  conda-forge
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libzlib-1.2.13             |       hd590300_5          60 KB  conda-forge
#     mathjax-2.7.7              |       ha770c72_3        21.2 MB  conda-forge
#     matplotlib-inline-0.1.6    |     pyhd8ed1ab_0          12 KB  conda-forge
#     multipledispatch-0.6.0     |             py_0          12 KB  conda-forge
#     nbformat-5.9.2             |     pyhd8ed1ab_0          98 KB  conda-forge
#     ncurses-6.4                |       h59595ed_2         864 KB  conda-forge
#     nest-asyncio-1.6.0         |     pyhd8ed1ab_0          11 KB  conda-forge
#     nlohmann_json-3.11.2       |       h27087fc_0         112 KB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     nss-3.97                   |       h1d7d5a4_0         1.9 MB  conda-forge
#     numpy-1.26.4               |  py310hb13e2d6_0         6.7 MB  conda-forge
#     openssl-3.2.1              |       hd590300_0         2.7 MB  conda-forge
#     optima-0.5.0               |  py310h020ca5c_0         711 KB  conda-forge
#     packaging-23.2             |     pyhd8ed1ab_0          48 KB  conda-forge
#     parso-0.8.3                |     pyhd8ed1ab_0          69 KB  conda-forge
#     pexpect-4.9.0              |     pyhd8ed1ab_0          52 KB  conda-forge
#     phreeqc4rkt-3.6.2.2        |       h00ab1b0_1         1.0 MB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     pip-24.0                   |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     pkgutil-resolve-name-1.3.10|     pyhd8ed1ab_1          11 KB  conda-forge
#     platformdirs-4.2.0         |     pyhd8ed1ab_0          20 KB  conda-forge
#     plotly-5.18.0              |     pyhd8ed1ab_0         4.9 MB  conda-forge
#     pluggy-1.4.0               |     pyhd8ed1ab_0          23 KB  conda-forge
#     prompt-toolkit-3.0.42      |     pyha770c72_0         264 KB  conda-forge
#     psutil-5.9.8               |  py310h2372a71_0         360 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     pure_eval-0.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
#     pybind11-2.11.1            |  py310hd41b1e2_2         179 KB  conda-forge
#     pybind11-abi-4             |       hd8ed1ab_3          10 KB  conda-forge
#     pybind11-global-2.11.1     |  py310hd41b1e2_2         168 KB  conda-forge
#     pycosat-0.6.6              |  py310h2372a71_0          85 KB  conda-forge
#     pygments-2.17.2            |     pyhd8ed1ab_0         840 KB  conda-forge
#     pyopenssl-24.0.0           |     pyhd8ed1ab_0         124 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-3.10.13             |hd12c33a_1_cpython        24.5 MB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python-fastjsonschema-2.19.1|     pyhd8ed1ab_0         220 KB  conda-forge
#     python-kaleido-0.2.1       |     pyhd8ed1ab_0          18 KB  conda-forge
#     python_abi-3.10            |          4_cp310           6 KB  conda-forge
#     pyzmq-25.1.2               |  py310h795f18f_0         446 KB  conda-forge
#     readline-8.2               |       h8228510_1         275 KB  conda-forge
#     reaktoro-2.11.0            |  py310h020ca5c_0         5.6 MB  conda-forge
#     reaktplot-0.4.1            |  py310heada3b3_2         115 KB  conda-forge
#     referencing-0.33.0         |     pyhd8ed1ab_0          38 KB  conda-forge
#     rpds-py-0.17.1             |  py310hcb5633a_0         994 KB  conda-forge
#     ruamel.yaml-0.17.40        |  py310h2372a71_0         196 KB  conda-forge
#     ruamel.yaml.clib-0.2.8     |  py310h2372a71_0         133 KB  conda-forge
#     ruamel_yaml-0.15.80        |py310h2372a71_1009         257 KB  conda-forge
#     setuptools-69.0.3          |     pyhd8ed1ab_0         460 KB  conda-forge
#     spdlog-1.12.0              |       hd2e6256_2         183 KB  conda-forge
#     stack_data-0.6.2           |     pyhd8ed1ab_0          26 KB  conda-forge
#     tenacity-8.2.3             |     pyhd8ed1ab_0          22 KB  conda-forge
#     thermofun-0.4.5            |  py310h64a2142_1         1.1 MB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     toolz-0.12.1               |     pyhd8ed1ab_0          51 KB  conda-forge
#     tornado-6.3.3              |  py310h2372a71_1         627 KB  conda-forge
#     traitlets-5.14.1           |     pyhd8ed1ab_0         108 KB  conda-forge
#     tsl_ordered_map-1.1.0      |       h00ab1b0_1          23 KB  conda-forge
#     typing_extensions-4.9.0    |     pyha770c72_0          35 KB  conda-forge
#     tzdata-2024a               |       h0c530f3_0         117 KB  conda-forge
#     wcwidth-0.2.13             |     pyhd8ed1ab_0          32 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     yaml-cpp4rkt-0.6.4.2       |       h00ab1b0_3         200 KB  conda-forge
#     zeromq-4.3.5               |       h59595ed_0         335 KB  conda-forge
#     zipp-3.17.0                |     pyhd8ed1ab_0          19 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       172.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          conda-forge/noarch::asttokens-2.4.1-pyhd8ed1ab_0
#   attrs              conda-forge/noarch::attrs-23.2.0-pyh71513ae_0
#   autodiff           conda-forge/linux-64::autodiff-1.0.3-py310h64a2142_1
#   boltons            conda-forge/noarch::boltons-23.1.1-pyhd8ed1ab_0
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   chemicalfun        conda-forge/linux-64::chemicalfun-0.1.10-py310hd41b1e2_0
#   comm               conda-forge/noarch::comm-0.2.1-pyhd8ed1ab_0
#   debugpy            conda-forge/linux-64::debugpy-1.8.0-py310hc6cd4ac_1
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#   eigen              conda-forge/linux-64::eigen-3.4.0-h00ab1b0_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.2.0-pyhd8ed1ab_2
#   executing          conda-forge/noarch::executing-2.0.1-pyhd8ed1ab_0
#   expat              conda-forge/linux-64::expat-2.5.0-hcb278e6_1
#   fmt                conda-forge/linux-64::fmt-10.2.1-h00ab1b0_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_1
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   importlib-metadata conda-forge/noarch::importlib-metadata-7.0.1-pyha770c72_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-7.0.1-hd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.1.1-pyhd8ed1ab_0
#   ipykernel          conda-forge/noarch::ipykernel-6.29.2-pyhd33586a_0
#   ipython            conda-forge/noarch::ipython-8.21.0-pyh707e725_0
#   jedi               conda-forge/noarch::jedi-0.19.1-pyhd8ed1ab_0
#   jsonpatch          conda-forge/noarch::jsonpatch-1.33-pyhd8ed1ab_0
#   jsonpointer        conda-forge/linux-64::jsonpointer-2.4-py310hff52083_3
#   jsonschema         conda-forge/noarch::jsonschema-4.21.1-pyhd8ed1ab_0
#   jsonschema-specif~ conda-forge/noarch::jsonschema-specifications-2023.12.1-pyhd8ed1ab_0
#   jupyter_client     conda-forge/noarch::jupyter_client-8.6.0-pyhd8ed1ab_0
#   jupyter_core       conda-forge/linux-64::jupyter_core-5.7.1-py310hff52083_0
#   kaleido-core       conda-forge/linux-64::kaleido-core-0.2.1-h3644ca4_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-21_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-21_linux64_openblas
#   libexpat           conda-forge/linux-64::libexpat-2.5.0-hcb278e6_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_5
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-ha4646dd_5
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-21_linux64_openblas
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.26-pthreads_h413a1c8_0
#   libpng             conda-forge/linux-64::libpng-1.6.42-h2797004_0
#   libsodium          conda-forge/linux-64::libsodium-1.0.18-h36c2ea0_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.44.2-h2797004_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-hd590300_5
#   mathjax            conda-forge/linux-64::mathjax-2.7.7-ha770c72_3
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.6-pyhd8ed1ab_0
#   multipledispatch   conda-forge/noarch::multipledispatch-0.6.0-py_0
#   nbformat           conda-forge/noarch::nbformat-5.9.2-pyhd8ed1ab_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.6.0-pyhd8ed1ab_0
#   nlohmann_json      conda-forge/linux-64::nlohmann_json-3.11.2-h27087fc_0
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.97-h1d7d5a4_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py310hb13e2d6_0
#   optima             conda-forge/linux-64::optima-0.5.0-py310h020ca5c_0
#   packaging          conda-forge/noarch::packaging-23.2-pyhd8ed1ab_0
#   parso              conda-forge/noarch::parso-0.8.3-pyhd8ed1ab_0
#   pexpect            conda-forge/noarch::pexpect-4.9.0-pyhd8ed1ab_0
#   phreeqc4rkt        conda-forge/linux-64::phreeqc4rkt-3.6.2.2-h00ab1b0_1
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_1
#   platformdirs       conda-forge/noarch::platformdirs-4.2.0-pyhd8ed1ab_0
#   plotly             conda-forge/noarch::plotly-5.18.0-pyhd8ed1ab_0
#   pluggy             conda-forge/noarch::pluggy-1.4.0-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.42-pyha770c72_0
#   psutil             conda-forge/linux-64::psutil-5.9.8-py310h2372a71_0
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   pure_eval          conda-forge/noarch::pure_eval-0.2.2-pyhd8ed1ab_0
#   pybind11           conda-forge/linux-64::pybind11-2.11.1-py310hd41b1e2_2
#   pybind11-abi       conda-forge/noarch::pybind11-abi-4-hd8ed1ab_3
#   pybind11-global    conda-forge/linux-64::pybind11-global-2.11.1-py310hd41b1e2_2
#   pygments           conda-forge/noarch::pygments-2.17.2-pyhd8ed1ab_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.19.1-pyhd8ed1ab_0
#   python-kaleido     conda-forge/noarch::python-kaleido-0.2.1-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.10-4_cp310
#   pyzmq              conda-forge/linux-64::pyzmq-25.1.2-py310h795f18f_0
#   reaktoro           conda-forge/linux-64::reaktoro-2.11.0-py310h020ca5c_0
#   reaktplot          conda-forge/linux-64::reaktplot-0.4.1-py310heada3b3_2
#   referencing        conda-forge/noarch::referencing-0.33.0-pyhd8ed1ab_0
#   rpds-py            conda-forge/linux-64::rpds-py-0.17.1-py310hcb5633a_0
#   ruamel.yaml        conda-forge/linux-64::ruamel.yaml-0.17.40-py310h2372a71_0
#   ruamel.yaml.clib   conda-forge/linux-64::ruamel.yaml.clib-0.2.8-py310h2372a71_0
#   spdlog             conda-forge/linux-64::spdlog-1.12.0-hd2e6256_2
#   stack_data         conda-forge/noarch::stack_data-0.6.2-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.2.3-pyhd8ed1ab_0
#   thermofun          conda-forge/linux-64::thermofun-0.4.5-py310h64a2142_1
#   toolz              conda-forge/noarch::toolz-0.12.1-pyhd8ed1ab_0
#   tornado            conda-forge/linux-64::tornado-6.3.3-py310h2372a71_1
#   traitlets          conda-forge/noarch::traitlets-5.14.1-pyhd8ed1ab_0
#   tsl_ordered_map    conda-forge/linux-64::tsl_ordered_map-1.1.0-h00ab1b0_1
#   typing_extensions  conda-forge/noarch::typing_extensions-4.9.0-pyha770c72_0
#   tzdata             conda-forge/noarch::tzdata-2024a-h0c530f3_0
#   wcwidth            conda-forge/noarch::wcwidth-0.2.13-pyhd8ed1ab_0
#   yaml-cpp4rkt       conda-forge/linux-64::yaml-cpp4rkt-0.6.4.2-h00ab1b0_3
#   zeromq             conda-forge/linux-64::zeromq-4.3.5-h59595ed_0
#   zipp               conda-forge/noarch::zipp-3.17.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   brotlipy           pkgs/main::brotlipy-0.7.0-py38h27cfd2~ --> conda-forge::brotlipy-0.7.0-py310h2372a71_1006
#   ca-certificates    pkgs/main::ca-certificates-2022.3.29-~ --> conda-forge::ca-certificates-2024.2.2-hbcca054_0
#   certifi            pkgs/main/linux-64::certifi-2021.10.8~ --> conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#   cffi                pkgs/main::cffi-1.15.0-py38hd667e15_1 --> conda-forge::cffi-1.16.0-py310h2fee648_0
#   conda              pkgs/main::conda-4.12.0-py38h06a4308_0 --> conda-forge::conda-23.7.4-py310hff52083_0
#   conda-package-han~ pkgs/main::conda-package-handling-1.8~ --> conda-forge::conda-package-handling-1.9.0-py310h5764c6d_1
#   cryptography       pkgs/main::cryptography-36.0.0-py38h9~ --> conda-forge::cryptography-42.0.2-py310hb8475ec_0
#   ld_impl_linux-64   pkgs/main::ld_impl_linux-64-2.35.1-h7~ --> conda-forge::ld_impl_linux-64-2.40-h41732ed_0
#   libffi                   pkgs/main::libffi-3.3-he6710b0_2 --> conda-forge::libffi-3.4.2-h7f98852_5
#   libgcc-ng          pkgs/main::libgcc-ng-9.3.0-h5101ec6_17 --> conda-forge::libgcc-ng-13.2.0-h807b86a_5
#   libgomp              pkgs/main::libgomp-9.3.0-h5101ec6_17 --> conda-forge::libgomp-13.2.0-h807b86a_5
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.3.0-hd4cf53~ --> conda-forge::libstdcxx-ng-13.2.0-h7e041cc_5
#   ncurses                 pkgs/main::ncurses-6.3-h7f8727e_2 --> conda-forge::ncurses-6.4-h59595ed_2
#   openssl              pkgs/main::openssl-1.1.1n-h7f8727e_0 --> conda-forge::openssl-3.2.1-hd590300_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py38h0~ --> conda-forge/noarch::pip-24.0-pyhd8ed1ab_0
#   pycosat            pkgs/main::pycosat-0.6.3-py38h7b6447c~ --> conda-forge::pycosat-0.6.6-py310h2372a71_0
#   pyopenssl          pkgs/main::pyopenssl-22.0.0-pyhd3eb1b~ --> conda-forge::pyopenssl-24.0.0-pyhd8ed1ab_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py3~ --> conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python                pkgs/main::python-3.8.13-h12debd9_0 --> conda-forge::python-3.10.13-hd12c33a_1_cpython
#   readline             pkgs/main::readline-8.1.2-h7f8727e_1 --> conda-forge::readline-8.2-h8228510_1
#   setuptools         pkgs/main/linux-64::setuptools-61.2.0~ --> conda-forge/noarch::setuptools-69.0.3-pyhd8ed1ab_0
#   tk                        pkgs/main::tk-8.6.11-h1ccaba5_0 --> conda-forge::tk-8.6.13-noxft_h4845f30_101
#   xz                         pkgs/main::xz-5.2.5-h7b6447c_0 --> conda-forge::xz-5.2.6-h166bdaf_0
#   zlib                    pkgs/main::zlib-1.2.12-h7f8727e_1 --> conda-forge::zlib-1.2.13-hd590300_5
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-4.5-1_gnu --> conda-forge::_openmp_mutex-4.5-2_gnu
#   ruamel_yaml        pkgs/main::ruamel_yaml-0.15.100-py38h~ --> conda-forge::ruamel_yaml-0.15.80-py310h2372a71_1009
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2024 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# ruamel.yaml.clib-0.2 | 133 KB    | : 100% 1.0/1 [00:00<00:00,  3.14it/s]
# freetype-2.12.1      | 620 KB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
# libblas-3.9.0        | 14 KB     | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  3.13it/s]
# asttokens-2.4.1      | 28 KB     | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# pyopenssl-24.0.0     | 124 KB    | : 100% 1.0/1 [00:00<00:00,  3.11it/s]
# platformdirs-4.2.0   | 20 KB     | : 100% 1.0/1 [00:00<00:00,  2.80it/s]
# prompt-toolkit-3.0.4 | 264 KB    | : 100% 1.0/1 [00:00<00:00,  2.19it/s]
# tk-8.6.13            | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
# font-ttf-inconsolata | 94 KB     | : 100% 1.0/1 [00:00<00:00, 11.02it/s]
# rpds-py-0.17.1       | 994 KB    | : 100% 1.0/1 [00:00<00:00,  2.10it/s]
# importlib-metadata-7 | 26 KB     | : 100% 1.0/1 [00:00<00:00,  2.31it/s]
# reaktoro-2.11.0      | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.03it/s]
# autodiff-1.0.3       | 703 KB    | : 100% 1.0/1 [00:00<00:00,  2.65it/s]
# importlib_metadata-7 | 9 KB      | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# libffi-3.4.2         | 57 KB     | : 100% 1.0/1 [00:00<00:00, 18.20it/s]
# pybind11-global-2.11 | 168 KB    | : 100% 1.0/1 [00:00<00:00,  2.90it/s]
# executing-2.0.1      | 27 KB     | : 100% 1.0/1 [00:00<00:00,  3.12it/s]
# debugpy-1.8.0        | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.83it/s]
# nss-3.97             | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.03it/s]
# python_abi-3.10      | 6 KB      | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# jsonschema-4.21.1    | 71 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# psutil-5.9.8         | 360 KB    | : 100% 1.0/1 [00:00<00:00,  3.02it/s]
# tsl_ordered_map-1.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  2.99it/s]
# python-fastjsonschem | 220 KB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# pybind11-abi-4       | 10 KB     | : 100% 1.0/1 [00:00<00:00, 17.33it/s]
# _openmp_mutex-4.5    | 23 KB     | : 100% 1.0/1 [00:00<00:00, 19.51it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 14.31it/s]
# setuptools-69.0.3    | 460 KB    | : 100% 1.0/1 [00:00<00:00,  2.76it/s]
# kaleido-core-0.2.1   | 59.2 MB   | : 100% 1.0/1 [00:12<00:00, 12.58s/it]
# libzlib-1.2.13       | 60 KB     | : 100% 1.0/1 [00:00<00:00,  3.19it/s]
# nest-asyncio-1.6.0   | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.00it/s]
# fmt-10.2.1           | 189 KB    | : 100% 1.0/1 [00:00<00:00,  3.14it/s]
# jsonpointer-2.4      | 16 KB     | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# nspr-4.35            | 222 KB    | : 100% 1.0/1 [00:00<00:00,  3.12it/s]
# stack_data-0.6.2     | 26 KB     | : 100% 1.0/1 [00:00<00:00,  3.25it/s]
# jupyter_client-8.6.0 | 103 KB    | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# python-3.10.13       | 24.5 MB   | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.72it/s]
# libgcc-ng-13.2.0     | 752 KB    | : 100% 1.0/1 [00:00<00:00,  3.07it/s]
# libsqlite-3.44.2     | 826 KB    | : 100% 1.0/1 [00:00<00:00,  2.34it/s]
# thermofun-0.4.5      | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# spdlog-1.12.0        | 183 KB    | : 100% 1.0/1 [00:00<00:00,  2.36it/s]
# ruamel.yaml-0.17.40  | 196 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# traitlets-5.14.1     | 108 KB    | : 100% 1.0/1 [00:00<00:00,  2.49it/s]
# jsonpatch-1.33       | 17 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# fontconfig-2.14.2    | 266 KB    | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# pysocks-1.7.1        | 19 KB     | : 100% 1.0/1 [00:00<00:00, 20.08it/s]
# libopenblas-0.3.26   | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.14it/s]
# ruamel_yaml-0.15.80  | 257 KB    | : 100% 1.0/1 [00:00<00:00,  2.82it/s]
# chemicalfun-0.1.10   | 374 KB    | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
# matplotlib-inline-0. | 12 KB     | : 100% 1.0/1 [00:00<00:00, 21.82it/s]
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:00<00:00,  5.40it/s]
# nlohmann_json-3.11.2 | 112 KB    | : 100% 1.0/1 [00:00<00:00, 11.73it/s]
# cffi-1.16.0          | 236 KB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
# jsonschema-specifica | 16 KB     | : 100% 1.0/1 [00:00<00:00,  3.22it/s]
# tenacity-8.2.3       | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# reaktplot-0.4.1      | 115 KB    | : 100% 1.0/1 [00:00<00:00,  2.09it/s]
# jedi-0.19.1          | 822 KB    | : 100% 1.0/1 [00:00<00:00,  1.78it/s]
# tornado-6.3.3        | 627 KB    | : 100% 1.0/1 [00:00<00:00,  2.75it/s]
# libgfortran5-13.2.0  | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
# brotlipy-0.7.0       | 310 KB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# zlib-1.2.13          | 91 KB     | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# mathjax-2.7.7        | 21.2 MB   | : 100% 1.0/1 [00:10<00:00, 10.65s/it]
# tzdata-2024a         | 117 KB    | : 100% 1.0/1 [00:00<00:00,  2.61it/s]
# comm-0.2.1           | 12 KB     | : 100% 1.0/1 [00:00<00:00,  3.21it/s]
# libgfortran-ng-13.2. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# libcblas-3.9.0       | 14 KB     | : 100% 1.0/1 [00:00<00:00,  3.24it/s]
# conda-package-handli | 1016 KB   | : 100% 1.0/1 [00:00<00:00,  3.75it/s]
# cryptography-42.0.2  | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.34it/s]
# ptyprocess-0.7.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00, 19.34it/s]
# exceptiongroup-1.2.0 | 20 KB     | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# conda-23.7.4         | 1006 KB   | : 100% 1.0/1 [00:00<00:00,  2.37it/s]
# expat-2.5.0          | 134 KB    | : 100% 1.0/1 [00:00<00:00,  2.78it/s]
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:00<00:00, 10.02it/s]
# libexpat-2.5.0       | 76 KB     | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
# libxcrypt-4.4.36     | 98 KB     | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# pluggy-1.4.0         | 23 KB     | : 100% 1.0/1 [00:00<00:00,  2.56it/s]
# pyzmq-25.1.2         | 446 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# xz-5.2.6             | 409 KB    | : 100% 1.0/1 [00:00<00:00,  6.33it/s]
# python-kaleido-0.2.1 | 18 KB     | : 100% 1.0/1 [00:00<00:00, 13.10it/s]
# zeromq-4.3.5         | 335 KB    | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# plotly-5.18.0        | 4.9 MB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
# wcwidth-0.2.13       | 32 KB     | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# liblapack-3.9.0      | 14 KB     | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# libstdcxx-ng-13.2.0  | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.68it/s]
# certifi-2024.2.2     | 157 KB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# bzip2-1.0.8          | 248 KB    | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# libsodium-1.0.18     | 366 KB    | : 100% 1.0/1 [00:00<00:00,  7.57it/s]
# yaml-cpp4rkt-0.6.4.2 | 200 KB    | : 100% 1.0/1 [00:00<00:00,  3.00it/s]
# jupyter_core-5.7.1   | 78 KB     | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# libuuid-2.38.1       | 33 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# pygments-2.17.2      | 840 KB    | : 100% 1.0/1 [00:00<00:00,  2.64it/s]
# optima-0.5.0         | 711 KB    | : 100% 1.0/1 [00:00<00:00,  2.90it/s]
# boltons-23.1.1       | 297 KB    | : 100% 1.0/1 [00:00<00:00,  3.09it/s]
# libpng-1.6.42        | 282 KB    | : 100% 1.0/1 [00:00<00:00,  3.07it/s]
# typing_extensions-4. | 35 KB     | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# referencing-0.33.0   | 38 KB     | : 100% 1.0/1 [00:00<00:00,  3.00it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 24.23it/s]
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
# phreeqc4rkt-3.6.2.2  | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.86it/s]
# pip-24.0             | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
# parso-0.8.3          | 69 KB     | : 100% 1.0/1 [00:00<00:00, 15.29it/s]
# nbformat-5.9.2       | 98 KB     | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# zipp-3.17.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# packaging-23.2       | 48 KB     | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# fonts-conda-forge-1  | 4 KB      | : 100% 1.0/1 [00:00<00:00, 24.99it/s]
# pycosat-0.6.6        | 85 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# libgomp-13.2.0       | 410 KB    | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00, 11.23it/s]
# ld_impl_linux-64-2.4 | 688 KB    | : 100% 1.0/1 [00:00<00:00,  3.02it/s]
# pexpect-4.9.0        | 52 KB     | : 100% 1.0/1 [00:00<00:00,  3.24it/s]
# pkgutil-resolve-name | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.28it/s]
# readline-8.2         | 275 KB    | : 100% 1.0/1 [00:00<00:00,  3.21it/s]
# importlib_resources- | 29 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# eigen-3.4.0          | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# multipledispatch-0.6 | 12 KB     | : 100% 1.0/1 [00:00<00:00, 19.09it/s]
# pybind11-2.11.1      | 179 KB    | : 100% 1.0/1 [00:00<00:00,  2.99it/s]
# ipython-8.21.0       | 578 KB    | : 100% 1.0/1 [00:00<00:00,  2.80it/s]
# ipykernel-6.29.2     | 115 KB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# pure_eval-0.2.2      | 14 KB     | : 100% 1.0/1 [00:00<00:00, 20.39it/s]
# openssl-3.2.1        | 2.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
# ncurses-6.4          | 864 KB    | : 100% 1.0/1 [00:00<00:00,  1.24it/s]
# pickleshare-0.7.5    | 9 KB      | : 100% 1.0/1 [00:00<00:00, 16.49it/s]
# toolz-0.12.1         | 51 KB     | : 100% 1.0/1 [00:00<00:00,  2.49it/s]
# attrs-23.2.0         | 53 KB     | : 100% 1.0/1 [00:00<00:00,  2.94it/s]
# done
# done
# done

# %%
import reaktoro as rkt
import numpy as np

# %%
db = rkt.SupcrtDatabase("supcrtbl")

##PYRITE
pyrite_mechanism1 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
pyrite_mechanism1.name="Neutral"
pyrite_mechanism1.lgk = -4.55
pyrite_mechanism1.E = 56.9
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="O2"
catalyst1.property="a"
catalyst1.power=0.5
pyrite_mechanism1.catalysts=[catalyst1]

pyrite_mechanism2 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
pyrite_mechanism2.name="Acid"
pyrite_mechanism2.lgk = -7.52
pyrite_mechanism2.E = 56.9
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="H+"
catalyst1.property="a"
catalyst1.power=-0.5
catalyst2 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst2.formula="Fe+3"
catalyst2.property="a"
catalyst2.power=0.5
pyrite_mechanism2.catalysts=[catalyst1, catalyst2]
pyrite_mechanisms = [pyrite_mechanism1, pyrite_mechanism2]

pyrite_reaction = rkt.GeneralReaction("Pyrite")
pyrite_reaction.setEquation("Pyrite + 2*H+ = Fe+2 + 2*HS-")

reaction_params = rkt.ReactionRateModelParamsPalandriKharaka()
reaction_params.mineral = "Pyrite"
reaction_params.mechanisms = pyrite_mechanisms
pyrite_reaction.setRateModel(rkt.ReactionRateModelPalandriKharaka(reaction_params))


##SIDERITE
siderite_mechanism1 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
siderite_mechanism1.name="Neutral"
siderite_mechanism1.lgk = -7.53
siderite_mechanism1.E = 52.2

siderite_mechanism2 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
siderite_mechanism2.name="Acid"
siderite_mechanism2.lgk = -3.19
siderite_mechanism2.E = 36.1
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="H+"
catalyst1.property="a"
catalyst1.power=0.5
siderite_mechanism2.catalysts=[catalyst1]

siderite_mechanisms = [siderite_mechanism1, siderite_mechanism2]

siderite_reaction = rkt.GeneralReaction("Siderite")
siderite_reaction.setEquation("Siderite = Fe+2 + CO3-2")

reaction_params = rkt.ReactionRateModelParamsPalandriKharaka()
reaction_params.mineral = "Siderite"
reaction_params.mechanisms = siderite_mechanisms
siderite_reaction.setRateModel(rkt.ReactionRateModelPalandriKharaka(reaction_params))


##CALCITE
calcite_mechanism1 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
calcite_mechanism1.name="Neutral"
calcite_mechanism1.lgk = -5.81
calcite_mechanism1.E = 23.5

calcite_mechanism2 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
calcite_mechanism2.name="Acid"
calcite_mechanism2.lgk = -0.30
calcite_mechanism2.E = 14.4
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="H+"
catalyst1.property="a"
catalyst1.power=1.0
calcite_mechanism2.catalysts=[catalyst1]

calcite_mechanism3 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
calcite_mechanism3.name= "Carbonate"
calcite_mechanism3.lgk = -3.48
calcite_mechanism3.E = 35.4
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="CO2"
catalyst1.property="P"
catalyst1.power=1.0
calcite_mechanism2.catalysts=[catalyst1]

calcite_mechanisms = [calcite_mechanism1, calcite_mechanism2, calcite_mechanism3]

calcite_reaction = rkt.GeneralReaction("Calcite")
calcite_reaction.setEquation("Calcite = Ca+2 + CO3-2")

reaction_params = rkt.ReactionRateModelParamsPalandriKharaka()
reaction_params.mineral = "Calcite"
reaction_params.mechanisms = calcite_mechanisms
calcite_reaction.setRateModel(rkt.ReactionRateModelPalandriKharaka(reaction_params))


##DOLOMITE
dolomite_mechanism1 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
dolomite_mechanism1.name="Neutral"
dolomite_mechanism1.lgk = -7.53
dolomite_mechanism1.E = 52.2

dolomite_mechanism2 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
dolomite_mechanism2.name="Acid"
dolomite_mechanism2.lgk = -3.19
dolomite_mechanism2.E = 36.1
catalyst1 = rkt.ReactionRateModelParamsPalandriKharakaCatalyst()
catalyst1.formula="H+"
catalyst1.property="a"
catalyst1.power=0.5
dolomite_mechanism2.catalysts=[catalyst1]

dolomite_mechanisms = [siderite_mechanism1, siderite_mechanism2]

dolomite_reaction = rkt.GeneralReaction("Dolomite")
dolomite_reaction.setEquation("Dolomite = Ca+2 + Mg+2 + 2*CO3-2")

reaction_params = rkt.ReactionRateModelParamsPalandriKharaka()
reaction_params.mineral = "Dolomite"
reaction_params.mechanisms = dolomite_mechanisms
dolomite_reaction.setRateModel(rkt.ReactionRateModelPalandriKharaka(reaction_params))


##ANKERITE
ankerite_mechanism1 = rkt.ReactionRateModelParamsPalandriKharakaMechanism()
ankerite_mechanism1.name="Neutral"
ankerite_mechanism1.lgk = -8.90
ankerite_mechanism1.E = 62.76

ankerite_mechanisms = [ankerite_mechanism1]

ankerite_reaction = rkt.GeneralReaction("Ankerite")
ankerite_reaction.setEquation("Ankerite = Ca+2 + Fe+2 + 2*CO3-2")

reaction_params = rkt.ReactionRateModelParamsPalandriKharaka()
reaction_params.mineral = "Ankerite"
reaction_params.mechanisms = ankerite_mechanisms
ankerite_reaction.setRateModel(rkt.ReactionRateModelPalandriKharaka(reaction_params))

# %%
species_concentrations = {
    'CO(aq)': 3.704707071227162e-16,
    'CO2(aq)': 2.086250256035096e-06,
    'CO3-2': 1.543780021191853e-07,
    'Fe+2': 1.985983986752736e-05,
    'Fe+3': 9.999999999999999e-21,
    'FeO(aq)': 8.736163894003929e-07,
    'FeO+':  4.737332300942274e-10,
    'FeO2-': 1.334997148684506e-07,
    'FeOH+': 2.148637703494536e-05,
    'FeOH+2': 2.526251546515949e-15,
    'HCO3-': 4.159157605878257e-05,
    'HFeO2(aq)': 4.641330580603335e-07,
    'HFeO2-': 3.555048455273015e-07,
    'H2O(aq)': 5.335666795463083e+01,
    'OH-': 1.993969545738213e-05,
    'H+': 2.294758342873325e-08,
    'H2S(aq)': 1.628376290415444e-09,
    'HS-': 2.277449020757749e-08,
    'HS2O3-': 1e-20,
    'HSO4-': 5.921519239618767e-11,
    'S2-2': 1.230856817908389e-18,
    'S2O3-2': 5.892159087706659e-17,
    'S3-2': 1e-20,
    'S4-2': 1e-20,
    'S5-2': 1e-20,
    'SO4-2': 3.024148008489608e-06,
    'H2S2O3(aq)': 1e-20,
    'HSO3-': 3.987377419123057e-15,
    'S4O6-2': 1e-20,
    'SO2(aq)': 4.669578255472613e-20,
    'SO3-2': 2.923941455936e-15,
    'Na+': 6.876849813972106e-05,
    'NaOH(aq)': 1.024960157903595e-09,
    'Cl-': 4.946889073310265e-05,
    'NaCl(aq)': 1.102755140875619e-09,
    'HCl(aq)': 1.991331972726705e-13,
    'Ca+2': 1.467203760065369e-06,
    'CaCO3(aq)': 2.391250697040307e-09,
    'CaOH+': 3.291677191102057e-09,
    'Mg+2': 3.832823285091968e-16,
    'MgCO3(aq)': 1.613939112740444e-19,
    'MgOH+': 4.916864543159515e-18,
    'K+': 1.402216335952764e-06,
    'KCl(aq)': 1.183043013185981e-12,
    'KOH(aq)': 2.044812874738915e-11,
    'KSO4-': 6.135162425576975e-11,
    'CaCl2(aq)': 1.301946688705578e-15,
    'CaCl+': 1.072568662633880e-10,
    'Siderite': 2.105900310807886e+02,
    'Pyrite': 8.163943740877280e-14 ,
    'Calcite': 8.163943740877279e-14,
    'Dolomite': 8.163943740877280e-14,
    'Ankerite': 8.163943740877281e-14
}

# %%
temperature = 96  # °C
outlet_pressure = 200e3  # 2 Bar

# %%
aqueous_species = ['CO(aq)', 'CO2(aq)', 'CO3-2', 'Fe+2', 'Fe+3', 'FeO(aq)', 'FeO+', 'FeO2-',
                   'FeOH+', 'FeOH+2', 'HCO3-', 'HFeO2(aq)', 'HFeO2-', 'H2O(aq)', 'OH-', 'H+', 'H2S(aq)',
                   'HS-', 'HS2O3-', 'HSO4-', 'S2-2', 'S2O3-2', 'S3-2', 'S4-2', 'S5-2', 'SO4-2',
                   'H2S2O3(aq)', 'HSO3-', 'S4O6-2', 'SO2(aq)', 'SO3-2', 'Na+', 'NaOH(aq)', 'Cl-',
                   'NaCl(aq)', 'HCl(aq)', 'Ca+2', 'CaCO3(aq)', 'CaOH+', 'Mg+2', 'MgCO3(aq)', 'MgOH+',
                   'K+', 'KCl(aq)', 'KOH(aq)', 'KSO4-', 'CaCl2(aq)', 'CaCl+']
mineral_species = ['Siderite', 'Pyrite', 'Calcite', 'Dolomite', 'Ankerite']

# %%
solution = rkt.AqueousPhase(aqueous_species)
solution.setActivityModel(rkt.chain(rkt.ActivityModelHKF(), rkt.ActivityModelDuanSun("CO2(aq)")))
def area_dolomite(props: rkt.ChemicalProps):
    return 4.19544653e-14
def area_pyrite(props: rkt.ChemicalProps):
    return 1.56045972e-14
def area_ankerite(props: rkt.ChemicalProps):
    return 4.30592549e-14
def area_calcite(props: rkt.ChemicalProps):
    return 2.40743606e-14
def area_siderite(props: rkt.ChemicalProps):
    return  49.3956209

t = 227.04761904761904 #s
phase_list = rkt.MineralPhases(mineral_species)
system = rkt.ChemicalSystem(db,
                            solution,
                            phase_list,
                            siderite_reaction,
                            pyrite_reaction,
                            calcite_reaction,
                            dolomite_reaction,
                            ankerite_reaction,
                            rkt.Surface("Siderite", area_siderite),
                            rkt.Surface("Pyrite", area_pyrite),
                            rkt.Surface("Calcite", area_calcite),
                            rkt.Surface("Dolomite", area_dolomite),
                            rkt.Surface("Ankerite", area_ankerite),
        )

# %% [markdown]
# Here we create options to properly solve the problem.

# %%
options = rkt.SmartKineticsOptions()
options.reltol = 1e-12
options.abstol = 1e-30
options.reltol_negative_amounts = -1e-30
options.learning.epsilon=1e-20
options.learning.optima.maxiters=2000
options.learning.optima.convergence.tolerance = 1e-8

# %% [markdown]
# In this case the solver works fine.

# %%
solver = rkt.SmartKineticsSolver(system)
solver.setOptions(options)

initial_brine_state = rkt.ChemicalState(system)
initial_brine_state.setTemperature(temperature, "celsius")
initial_brine_state.setPressure(outlet_pressure, "Pa")
for species, concentration in species_concentrations.items():
     initial_brine_state.set(species, concentration, "mol")
solver.solve(initial_brine_state, t)

print(initial_brine_state)
# Out:
# +-------------------------+------------+------+
# | Property                |      Value | Unit |
# +-------------------------+------------+------+
# | Temperature             |   369.1500 |    K |
# | Pressure                |     2.0000 |  bar |
# | Charge:                 | 1.6269e-05 |  mol |
# | Element Amount:         |            |      |
# | :: H                    | 1.0671e+02 |  mol |
# | :: C                    | 2.1059e+02 |  mol |
# | :: O                    | 6.8513e+02 |  mol |
# | :: Na                   | 6.8771e-05 |  mol |
# | :: Mg                   | 2.4081e-08 |  mol |
# | :: S                    | 3.1919e-06 |  mol |
# | :: Cl                   | 4.9470e-05 |  mol |
# | :: K                    | 1.4023e-06 |  mol |
# | :: Ca                   | 1.5564e-06 |  mol |
# | :: Fe                   | 2.1059e+02 |  mol |
# | Species Amount:         |            |      |
# | :: CO(aq)               | 3.9340e-19 |  mol |
# | :: CO2(aq)              | 1.9695e-06 |  mol |
# | :: CO3-2                | 1.0181e-20 |  mol |
# | :: Fe+2                 | 1.7613e-05 |  mol |
# | :: Fe+3                 | 1.0054e-20 |  mol |
# | :: FeO(aq)              | 7.3560e-07 |  mol |
# | :: FeO+                 | 6.7517e-15 |  mol |
# | :: FeO2-                | 1.0060e-12 |  mol |
# | :: FeOH+                | 3.0418e-05 |  mol |
# | :: FeOH+2               | 1.3337e-17 |  mol |
# | :: HCO3-                | 4.7637e-05 |  mol |
# | :: HFeO2(aq)            | 1.1591e-20 |  mol |
# | :: HFeO2-               | 5.3921e-10 |  mol |
# | :: H2O(aq)              | 5.3357e+01 |  mol |
# | :: OH-                  | 1.9371e-05 |  mol |
# | :: H+                   | 1.0019e-20 |  mol |
# | :: H2S(aq)              | 4.5812e-11 |  mol |
# | :: HS-                  | 1.0000e-20 |  mol |
# | :: HS2O3-               | 4.2960e-20 |  mol |
# | :: HSO4-                | 3.2399e-11 |  mol |
# | :: S2-2                 | 1.0727e-20 |  mol |
# | :: S2O3-2               | 1.9400e-14 |  mol |
# | :: S3-2                 | 1.0106e-20 |  mol |
# | :: S4-2                 | 1.0040e-20 |  mol |
# | :: S5-2                 | 1.0000e-20 |  mol |
# | :: SO4-2                | 3.0823e-06 |  mol |
# | :: H2S2O3(aq)           | 1.0800e-20 |  mol |
# | :: HSO3-                | 3.7059e-13 |  mol |
# | :: S4O6-2               | 1.0126e-20 |  mol |
# | :: SO2(aq)              | 2.6099e-18 |  mol |
# | :: SO3-2                | 3.8754e-13 |  mol |
# | :: Na+                  | 6.8770e-05 |  mol |
# | :: NaOH(aq)             | 1.8585e-14 |  mol |
# | :: Cl-                  | 4.9469e-05 |  mol |
# | :: NaCl(aq)             | 1.1025e-09 |  mol |
# | :: HCl(aq)              | 1.1149e-13 |  mol |
# | :: Ca+2                 | 1.4913e-06 |  mol |
# | :: CaCO3(aq)            | 4.2132e-12 |  mol |
# | :: CaOH+                | 6.5125e-08 |  mol |
# | :: Mg+2                 | 2.4060e-08 |  mol |
# | :: MgCO3(aq)            | 1.0125e-20 |  mol |
# | :: MgOH+                | 2.1452e-11 |  mol |
# | :: K+                   | 1.4022e-06 |  mol |
# | :: KCl(aq)              | 1.1829e-12 |  mol |
# | :: KOH(aq)              | 1.4054e-12 |  mol |
# | :: KSO4-                | 6.2516e-11 |  mol |
# | :: CaCl2(aq)            | 1.5496e-16 |  mol |
# | :: CaCl+                | 1.0564e-15 |  mol |
# | :: Siderite :: FeCO3    | 2.1059e+02 |  mol |
# | :: Pyrite :: FeS2       | 5.4752e-08 |  mol |
# | :: Calcite :: CaCO3     | 1.0000e-20 |  mol |
# | :: Dolomite :: CaMgC2O6 | 1.0000e-20 |  mol |
# | :: Ankerite :: CaFeC2O6 | 1.0000e-20 |  mol |
# +-------------------------+------------+------+

# %% [markdown]
# Now to exemplify the error we set epsilon to 0.1 and then restore its value and try to solve the same problem.

# %%
options.learning.epsilon=1e-1

solver = rkt.SmartKineticsSolver(system)
solver.setOptions(options)

initial_brine_state = rkt.ChemicalState(system)
initial_brine_state.setTemperature(temperature, "celsius")
initial_brine_state.setPressure(outlet_pressure, "Pa")
for species, concentration in species_concentrations.items():
     initial_brine_state.set(species, concentration, "mol")
solver.solve(initial_brine_state, t)


options.learning.epsilon=1e-20
solver.setOptions(options)

initial_brine_state = rkt.ChemicalState(system)
initial_brine_state.setTemperature(temperature, "celsius")
initial_brine_state.setPressure(outlet_pressure, "Pa")
for species, concentration in species_concentrations.items():
     initial_brine_state.set(species, concentration, "mol")
solver.solve(initial_brine_state, t)

print(initial_brine_state)
# Out:
# +-------------------------+----------+------+
# | Property                |    Value | Unit |
# +-------------------------+----------+------+
# | Temperature             | 369.1500 |    K |
# | Pressure                |   2.0000 |  bar |
# | Charge:                 |      nan |  mol |
# | Element Amount:         |          |      |
# | :: H                    |      nan |  mol |
# | :: C                    |      nan |  mol |
# | :: O                    |      nan |  mol |
# | :: Na                   |      nan |  mol |
# | :: Mg                   |      nan |  mol |
# | :: S                    |      nan |  mol |
# | :: Cl                   |      nan |  mol |
# | :: K                    |      nan |  mol |
# | :: Ca                   |      nan |  mol |
# | :: Fe                   |      nan |  mol |
# | Species Amount:         |          |      |
# | :: CO(aq)               |      nan |  mol |
# | :: CO2(aq)              |      nan |  mol |
# | :: CO3-2                |      nan |  mol |
# | :: Fe+2                 |      nan |  mol |
# | :: Fe+3                 |     -nan |  mol |
# | :: FeO(aq)              |     -nan |  mol |
# | :: FeO+                 |     -nan |  mol |
# | :: FeO2-                |      nan |  mol |
# | :: FeOH+                |      nan |  mol |
# | :: FeOH+2               |     -nan |  mol |
# | :: HCO3-                |      nan |  mol |
# | :: HFeO2(aq)            |      nan |  mol |
# | :: HFeO2-               |      nan |  mol |
# | :: H2O(aq)              |      nan |  mol |
# | :: OH-                  |      nan |  mol |
# | :: H+                   |      nan |  mol |
# | :: H2S(aq)              |      nan |  mol |
# | :: HS-                  |     -nan |  mol |
# | :: HS2O3-               |      nan |  mol |
# | :: HSO4-                |      nan |  mol |
# | :: S2-2                 |     -nan |  mol |
# | :: S2O3-2               |      nan |  mol |
# | :: S3-2                 |      nan |  mol |
# | :: S4-2                 |     -nan |  mol |
# | :: S5-2                 |      nan |  mol |
# | :: SO4-2                |     -nan |  mol |
# | :: H2S2O3(aq)           |      nan |  mol |
# | :: HSO3-                |      nan |  mol |
# | :: S4O6-2               |     -nan |  mol |
# | :: SO2(aq)              |     -nan |  mol |
# | :: SO3-2                |     -nan |  mol |
# | :: Na+                  |      nan |  mol |
# | :: NaOH(aq)             |      nan |  mol |
# | :: Cl-                  |      nan |  mol |
# | :: NaCl(aq)             |      nan |  mol |
# | :: HCl(aq)              |     -nan |  mol |
# | :: Ca+2                 |     -nan |  mol |
# | :: CaCO3(aq)            |      nan |  mol |
# | :: CaOH+                |     -nan |  mol |
# | :: Mg+2                 |     -nan |  mol |
# | :: MgCO3(aq)            |      nan |  mol |
# | :: MgOH+                |      nan |  mol |
# | :: K+                   |      nan |  mol |
# | :: KCl(aq)              |      nan |  mol |
# | :: KOH(aq)              |      nan |  mol |
# | :: KSO4-                |     -nan |  mol |
# | :: CaCl2(aq)            |     -nan |  mol |
# | :: CaCl+                |      nan |  mol |
# | :: Siderite :: FeCO3    |     -nan |  mol |
# | :: Pyrite :: FeS2       |     -nan |  mol |
# | :: Calcite :: CaCO3     |     -nan |  mol |
# | :: Dolomite :: CaMgC2O6 |     -nan |  mol |
# | :: Ankerite :: CaFeC2O6 |     -nan |  mol |
# +-------------------------+----------+------+
